# %% [markdown]
# # Language Map of Europe
# Welcome to the language map of Europe repository. Readme file here: [README.MD](README.md)
#
# Few general points to note:
# -  Translations are generated by Google Translate. Some may be inaccurate or use non-European (i.e. Latin American Spanish) words.
# -  This project uses the unofficial library accessing the web API of translate.google.com. This API does not guarantee that the library would work properly at all times. If you get HTTP 5xx error or errors like #6, it’s probably because Google has banned your IP address.
# -  Only one translation is provided for each word; multiple meaning words might not display correctly.
# -  English word might show if local language translation is not available.
# -  Greek and Cyrillic alphabets are transliterated to Latin
# -  The color algorythm is not 100% accurate - any suggestions and improvements are welcome!

# %%
exec(open("langmap.py").read())
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d1ef6ffc-05c7-4394-ac18-daa8e3241d98">Loading BokehJS ...</span>
#     </div>
# Enter English word to translate:beer
#   <div class="bk-root" id="14ea9b0c-f64e-4c03-a8ea-98b9b7a5e299"></div>
